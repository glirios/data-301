# %% [markdown]
# # Day 10
#
# * Introduction to Data Science (Data 301)
# * Cal Poly, Winter 2017
# * Brian E. Granger

# %% [markdown]
# ## Announcements

# %% [markdown]
# ## In class
#
# * Grab materials for the day
#   - `cd` - go back to your home directory
#   - `nbgrader list --course data301`
#   - `nbgrader fetch --course data301 day10`
#   - `nbgrader fetch --course data301 assignment09`
# * To reset/update course materials:
#   - `cd`
#   - `cd data301`
#   - `make update`
# * Today's material
#   - Merge, join
#   - Grouping, aggregation
#   - Time series

# %% [markdown]
# ## Out of class
#
# * Complete `assignment09` by the beginning of class, Tuesday, day 11.
