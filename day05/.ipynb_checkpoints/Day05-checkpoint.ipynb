# %% [markdown]
# # Day 5
#
# * Introduction to Data Science (Data 301)
# * Cal Poly, Winter 2017
# * Brian E. Granger

# %% [markdown]
# ## Announcements

# %% [markdown]
# * Midterm coming on day 9 of class (Feb 7th).
# * **Server down from 10pm to midnight tonight!**

# %% [markdown]
# ## In class
#
# * Grab materials for the day
#   - `cd` - go back to your home directory
#   - `nbgrader list --course data301`
#   - `nbgrader fetch --course data301 day05`
#   - `nbgrader fetch --course data301 assignment05`
# * Turn in `assignment04`:
#   * Restart the kernel and run all notebooks to make sure you code works!
#   * `nbgrader submit --course data301 assignment04`
# * To reset/update course materials:
#   - `cd`
#   - `cd data301`
#   - `make update`
# * Today's material
#   - Seattle Weather Data
#   - Basic Data Transformation
#   - Exploratory Data Analysis

# %% [markdown]
# ## Out of class
#
# * Complete `assignment05` by the beginning of class, Thursday, day 6.
