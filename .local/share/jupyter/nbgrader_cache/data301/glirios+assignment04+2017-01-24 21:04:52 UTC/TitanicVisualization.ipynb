# %% [markdown]
# # Titanic Visualization

# %% [markdown]
# ## Imports

# %%
from altair import *

# %%
from seaborn.utils import load_dataset as lds

# %%
df = lds('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who adult_male deck  embark_town alive  alone
# 0    man       True  NaN  Southampton    no  False
# 1  woman      False    C    Cherbourg   yes  False
# 2  woman      False  NaN  Southampton   yes   True
# 3  woman      False    C  Southampton   yes  False
# 4    man       True  NaN  Southampton    no   True

# %% [markdown]
# # Age, sex and class
#
# Create a visualization to answer the following question:
#
# > How do the age, sex and class affect whether the person survived?
#
# Build your visualization using:
#
# * Tick marks
# * X -> age
# * Y -> sex
# * Color -> survived
# * Row -> class

# %%
# YOUR CODE HERE
Chart(df).mark_tick().encode(
    x='age',
    y='sex',
    row='class',
    color='survived',
)
# Out:
# <div class="vega-embed" id="c08535c2-1d02-4023-9a1a-8c7e99349234"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# # Age and fare
#
# Create a visualization to answer the following question:
#
# > Are there interesting patterns in the age, fare space related to a passenger surviving or not?
#
# Build your visualization using:
#
# * Point marks
# * X -> age
# * Y -> fare on a log scale
# * Color -> survived on a scale with green for survived and red for not
# * Row -> sex
# * Size -> class on a scale with Third the smallest and First the largest

# %%
# YOUR CODE HERE
Chart(df).mark_point().encode(
    X('age'),
    Y('fare', scale = Scale(type='log')),
    Color('survived:N', scale = Scale(range=["red","green"])),
    Size('class', scale = Scale(domain=['Third','Second','First'])),
    row='sex',
)
# Out:
# <div class="vega-embed" id="30e2aa90-a769-4bdf-b32c-ccf2bb778035"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# # Fare distribution
#
# Create a visualization to answer the following question:
#
# > How does the fare distribution vary with geographic region?
#
# Build your visualization using:
#
# * Bar marks as a histogram
# * X -> binned fare with at most 100 bins
# * Y -> the number of records, with 3 labeled ticks and a title of `N`
# * Row -> embark town, with a custom title of `Town`
# * A custom cell size of height 60 and width 240

# %%
# YOUR CODE HERE
Chart(df).mark_bar().encode(
    X('fare', bin=Bin(maxbins=100)),
    Y('count(*):Q', title='N', axis= Axis(ticks=3)),
    Row('embark_town', title = 'Town'),
).configure_cell(width= 240, height=60)
# Out:
# <div class="vega-embed" id="30217215-7150-445f-b7e7-b5d0f9bfbd49"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
