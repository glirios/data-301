# %% [markdown]
# # Student Alcohol Usage and Grades

# %% [markdown]
# In this notebook you will perform exploratory data analysis on a dataset from Kaggle about student alcohol usage, grades and other personal and family background information. The dataset can be found here:
#
# https://www.kaggle.com/uciml/student-alcohol-consumption
#
# This page also contains a description of the measured variables. After each visualization you will be asked to draw conclusions based on the visualization. You will write those conclusions in complete sentences. Imagine yourself presenting this notebook to the school board members, who are not intereste in code and data. Your conclusions should be written so that an audience such as this could make informed decisions from your analysis.

# %% [markdown]
# ## Imports

# %%
from altair import *
import pandas as pd

# %% [markdown]
# ## Data
#
# Here we import the data as a Pandas `DataFrame`:

# %%
students = pd.read_csv('/data/student-alcohol-consumption/student-mat.csv')

# %%
students.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
len(students)
# Out:
# 395

# %%
students.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# ## What things are correlated with alchohol usage?
#
# The first things we will explore is alcohol usage. There are a number of variables in this dataset that may display covariation or correlation with alcohol usage. Before exploring these things, create a new variable for total alcohol usage (sum of the workday and weekend alcohol usage). Name this new column `Talc` in the `DataFrame` `Talc`:

# %%
# YOUR CODE HERE
students['Talc'] = students.Dalc + students.Walc

# %%
assert 'Talc' in students.columns
assert students.Talc.dtype==int

# %% [markdown]
# In the next cell create a visualization that shows the variation of total alcohol usage:

# %%
# YOUR CODE HERE
Chart(students).mark_bar().encode(
    x ='Talc',
    y = 'count(*):Q'
)
# Out:
# <div class="vega-embed" id="bbfa50a2-bfbf-4956-b703-2369f4e17723"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# In the next markdown cell describe your conclusions from this visualization in complete sentences:

# %% [markdown]
# According to the graph, our data shows that people see themselves as low comsumers of alcohol through out the week. There seems to be a trend with the exception of 10 that as the total comsumption range get high there are fewer people that place themselves in that range.

# %% [markdown]
# In the next cell, create a visualization that helps answer the following question:
#
# > Does internet access at home show covariation with alcohol usage?

# %%
# YOUR CODE HERE
Chart(students).mark_point().encode(
    X('Talc'),
    Y('count(*)'),
    Color('internet')
)
# Out:
# <div class="vega-embed" id="abb12623-59ef-4572-8bdd-1c1208bef50a"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# In the next markdown cell describe your conclusions from this visualization in complete sentences:

# %% [markdown]
# There seems to be a correlation with internet and total alcohol consumption where there is an increase in the number of people in each level of alcohol consumption with people with internet. It may be the possibility that since the internet is easily available that it will show up as an apparent correlation.

# %% [markdown]
# In the next cell, create a visualization that helps answers the following question:
#
# > Is going out with friends correlated with total alcohol usage?

# %%
# YOUR CODE HERE
Chart(students).mark_point().encode(
    X('goout', title='Going Out'),
    Y('average(Talc)', title='Talc'),
)
# Out:
# <div class="vega-embed" id="fc752d12-a658-4439-aefb-568efbb3556e"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# In the next markdown cell describe your conclusions from this visualization in complete sentences:

# %% [markdown]
# There seems to be a correlation between total alcohol usage and going out with friends.

# %% [markdown]
# In the next cell, create a visualization that helps answers the following question:
#
# > What is the relationship between time spent studying and total alcohol usage?

# %%
# YOUR CODE HERE
Chart(students).mark_point().encode(
    X('studytime', title='Study Time'),
    Y('average(Talc)', title='Talc'),
)
# Out:
# <div class="vega-embed" id="fc06bfcb-9265-46ef-84fd-6c2c51348cea"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# In the next markdown cell describe your conclusions from this visualization in complete sentences:

# %% [markdown]
# The relationship between total alcohol use and study time seems to be evident. When the data shows with just total alcohol usage points, total alcohol usage does not seem to show an relationship. According to this graph, it shows that there is a relatinoship between total alcohol usage and study time. As the level of study time increases, total alcohol usage increases as well.

# %% [markdown]
# ## What things are correlated with getting good grades?

# %% [markdown]
# In the next cell, create a visualization that helps answers the following question:
#
# > How do student's plans to attend higher education correlate with their grades?

# %%
# YOUR CODE HERE
Chart(students).mark_point().encode(
    X('G3'),
    Y('higher'),
)
# Out:
# <div class="vega-embed" id="76b57021-fe10-4081-bd75-bc92629e80d2"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# In the next markdown cell describe your conclusions from this visualization in complete sentences:

# %% [markdown]
# Those that plan to go to higher education seem to have a wide range of grade points. Those that are not looking into higher education seems to range very centralized. With students hoping to reach higher education, there is a wider range and there are many students with higher grades.

# %% [markdown]
# In the next cell, create a visualization that helps answers the following question:
#
# > Does a student's mothers education show covariation with their grades?

# %%
# YOUR CODE HERE
Chart(students).mark_point().encode(
    X('G1'),
    Y('G2'),
    Color('Medu:N', scale = Scale(range =["#9467bd", "green", 'red', '#e7ba52', '#1f77b4'])),
)
# Out:
# <div class="vega-embed" id="c7be94b1-beaa-4ee8-84a5-8f465f57e0dc"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# In the next markdown cell describe your conclusions from this visualization in complete sentences:

# %% [markdown]
# There seems to be a relationship between grades and thier mother's education. The reason for the relationship could be the cause of the fact that they might be aiding their children in their homework.
