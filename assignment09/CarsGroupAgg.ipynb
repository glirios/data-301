# %% [markdown]
# # Cars: Grouping and Aggregation

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from altair import load_dataset

# %% [markdown]
# ## Dataset

# %%
cars = load_dataset('cars')

# %%
cars.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8         307.0       130.0              18.0
# 1          11.5          8         350.0       165.0              15.0
# 2          11.0          8         318.0       150.0              18.0
# 3          12.0          8         304.0       150.0              16.0
# 4          10.5          8         302.0       140.0              17.0
#
#                         Name Origin  Weight_in_lbs        Year
# 0  chevrolet chevelle malibu    USA           3504  1970-01-01
# 1          buick skylark 320    USA           3693  1970-01-01
# 2         plymouth satellite    USA           3436  1970-01-01
# 3              amc rebel sst    USA           3433  1970-01-01
# 4                ford torino    USA           3449  1970-01-01

# %%
len(cars)
# Out:
# 406

# %% [markdown]
# ## Grouped mean

# %% [markdown]
# Compute the average of `Acceleration`, `Displacement` and `Horsepower`, grouped by `Origin`:

# %%
# YOUR CODE HERE
g1 = pd.DataFrame(cars.groupby('Origin')['Acceleration', 'Displacement', 'Horsepower'].mean())
g1
# Out:
#         Acceleration  Displacement  Horsepower
# Origin
# Europe     16.821918    109.465753   81.000000
# Japan      16.172152    102.708861   79.835443
# USA        14.942520    247.935039  119.900000

# %%
assert list(g1.columns)==['Acceleration', 'Displacement', 'Horsepower']
assert list(g1.index)==['Europe', 'Japan', 'USA']

# %% [markdown]
# Find the maximum `Acceleration` and `Displacement` grouped by `Origin` and `Cylinders`:

# %%
# YOUR CODE HERE
g2 = pd.DataFrame(cars.groupby(['Origin', 'Cylinders'])['Acceleration', 'Displacement'].max())
g2
# Out:
#                   Acceleration  Displacement
# Origin Cylinders
# Europe 4                  24.8         146.0
#        5                  20.1         183.0
#        6                  19.6         168.0
# Japan  3                  13.5          80.0
#        4                  21.0         144.0
#        6                  15.5         168.0
# USA    4                  22.2         156.0
#        6                  21.0         262.0
#        8                  22.2         455.0

# %%
assert list(g2.columns)==['Acceleration', 'Displacement']
assert [list(i) for i in list(g2.index.levels)]==[['Europe', 'Japan', 'USA'], [3, 4, 5, 6, 8]]

# %% [markdown]
# ## Grouped counts

# %% [markdown]
# Compute the number of cars, grouped by `Year` and `Cylinders` and unstack the result:

# %%
# YOUR CODE HERE
g3 = cars.groupby(['Year','Cylinders'])['Cylinders'].sum().unstack()
g3
# Out:
# Cylinders     3      4    5     6      8
# Year
# 1970-01-01  NaN   32.0  NaN  24.0  184.0
# 1971-01-01  NaN   56.0  NaN  48.0   56.0
# 1972-01-01  3.0   56.0  NaN   NaN  104.0
# 1973-01-01  3.0   44.0  NaN  48.0  160.0
# 1974-01-01  NaN   60.0  NaN  42.0   40.0
# 1975-01-01  NaN   48.0  NaN  72.0   48.0
# 1976-01-01  NaN   60.0  NaN  60.0   72.0
# 1977-01-01  3.0   56.0  NaN  30.0   64.0
# 1978-01-01  NaN   68.0  5.0  72.0   48.0
# 1979-01-01  NaN   48.0  5.0  36.0   80.0
# 1980-01-01  3.0  100.0  5.0  12.0    NaN
# 1982-01-01  NaN  200.0  NaN  60.0    8.0

# %%
assert list(g3.columns)==[3, 4, 5, 6, 8]
assert list(g3.index)==['1970-01-01', '1971-01-01', '1972-01-01', '1973-01-01',
                        '1974-01-01', '1975-01-01', '1976-01-01', '1977-01-01', 
                        '1978-01-01', '1979-01-01', '1980-01-01', '1982-01-01']

# %% [markdown]
# ## Multiple aggregations for different columns

# %% [markdown]
# Compute two aggregate quantities with the following names and values:
#
# * `min_mpg` as the minimum `Miles_per_Gallon`.
# * `max_mpg` as the maximum `Miles_per_Gallon`.
#
# Group by `Origin`:

# %%
# YOUR CODE HERE
g4 = cars.groupby('Origin')['Miles_per_Gallon'].aggregate({'min_mpg': 'min',
                                                           'max_mpg': 'max'
                                                    })
g4 = g4[['max_mpg', 'min_mpg']]
g4
# Out:
#         max_mpg  min_mpg
# Origin
# Europe     44.3     16.2
# Japan      46.6     18.0
# USA        39.0      9.0

# %%
assert list(g4.columns)==['max_mpg', 'min_mpg']
assert list(g4.index)==['Europe', 'Japan', 'USA']

# %% [markdown]
# ## Custom aggregation function

# %% [markdown]
# Compute the range of cylinders (`range` = max - min) grouped by `Origin`:

# %%
# YOUR CODE HERE
g5 = cars.groupby('Origin')['Cylinders'].aggregate({'range': lambda x: x.max() - x.min()})
g5
# Out:
#         range
# Origin
# Europe      2
# Japan       3
# USA         4

# %%
assert list(g5.columns)==['range']
assert list(g5.index)==['Europe', 'Japan', 'USA']

# %% [markdown]
# ## Group filtering

# %% [markdown]
# Compute the average acceleration, grouped by `Year` and `Origin`, only including groups with a max number of Cylinders less than 6. Unstack the `Origin` level of the resulting hierarchical row index:

# %%
# YOUR CODE HERE
def filter_cyl(x):
    return x['Cylinders'].max() < 6

test = cars.groupby(['Year','Origin']).filter(filter_cyl)
g6 = pd.DataFrame(test.groupby(['Year','Origin'])['Acceleration'].mean()).unstack()
g6
# Out:
#            Acceleration
# Origin           Europe      Japan
# Year
# 1970-01-01    16.666667  14.750000
# 1971-01-01    17.400000  16.375000
# 1972-01-01    18.700000  15.400000
# 1973-01-01    16.428571        NaN
# 1974-01-01    15.333333  17.666667
# 1975-01-01    15.083333  16.000000
# 1977-01-01    15.000000        NaN
# 1978-01-01          NaN  16.200000
# 1979-01-01    18.400000  17.200000
# 1980-01-01    18.366667        NaN

# %%
assert [list(i) for i in list(g6.columns.levels)]==[['Acceleration'], ['Europe', 'Japan']]
assert g6.index.name=='Year'
assert len(g6)==10

# %% [markdown]
# ## Grouped z-scores

# %% [markdown]
# Here is the average `Miles_per_Gallon`, grouped by `Year`:

# %%
cars.groupby(['Year'])['Miles_per_Gallon'].mean()
# Out:
# Year
# 1970-01-01    17.689655
# 1971-01-01    21.250000
# 1972-01-01    18.714286
# 1973-01-01    17.100000
# 1974-01-01    22.703704
# 1975-01-01    20.266667
# 1976-01-01    21.573529
# 1977-01-01    23.375000
# 1978-01-01    24.061111
# 1979-01-01    25.093103
# 1980-01-01    33.696552
# 1982-01-01    31.045000
# Name: Miles_per_Gallon, dtype: float64

# %% [markdown]
# Replace the `Miles_per_Gallon` values by the [z-score](https://en.wikipedia.org/wiki/Standard_score) of that value relative to its group for each `Year`:

# %%
# YOUR CODE HERE
def z_score(x):
    x['Miles_per_Gallon'] = (x['Miles_per_Gallon'] - x['Miles_per_Gallon'].mean())/ x['Miles_per_Gallon'].std()
    return x

d7 = pd.DataFrame(cars.groupby(['Year']).apply(z_score).dropna())
d7
# Out:
#      Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0            12.0          8         307.0       130.0          0.058125
# 1            11.5          8         350.0       165.0         -0.503753
# 2            11.0          8         318.0       150.0          0.058125
# 3            12.0          8         304.0       150.0         -0.316460
# 4            10.5          8         302.0       140.0         -0.129168
# 5            10.0          8         429.0       198.0         -0.503753
# 6             9.0          8         454.0       220.0         -0.691046
# 7             8.5          8         440.0       215.0         -0.691046
# 8            10.0          8         455.0       225.0         -0.691046
# 9             8.5          8         390.0       190.0         -0.503753
# 15           10.0          8         383.0       170.0         -0.503753
# 16            8.0          8         340.0       160.0         -0.691046
# 18            9.5          8         400.0       150.0         -0.503753
# 19           10.0          8         455.0       225.0         -0.691046
# 20           15.0          4         113.0        95.0          1.181883
# 21           15.5          6         198.0        95.0          0.807297
# 22           15.5          6         199.0        97.0          0.058125
# 23           16.0          6         200.0        85.0          0.620004
# 24           14.5          4          97.0        88.0          1.743761
# 25           20.5          4          97.0        46.0          1.556468
# 26           17.5          4         110.0        87.0          1.369176
# 27           14.5          4         107.0        90.0          1.181883
# 28           17.5          4         104.0        95.0          1.369176
# 29           12.5          4         121.0       113.0          1.556468
# 30           15.0          6         199.0        90.0          0.620004
# 31           14.0          8         360.0       215.0         -1.440218
# 32           15.0          8         307.0       200.0         -1.440218
# 33           13.5          8         318.0       210.0         -1.252925
# 34           18.5          8         304.0       193.0         -1.627511
# 35           14.5          4          97.0        88.0          0.872277
# ..            ...        ...           ...         ...               ...
# 375          19.6          4         112.0        88.0         -0.554978
# 376          18.6          4         112.0        88.0         -0.737237
# 377          18.0          4         112.0        88.0          0.538575
# 378          16.2          4         112.0        85.0         -0.008202
# 379          16.0          4         135.0        84.0         -0.372720
# 380          18.0          4         151.0        90.0         -0.737237
# 381          16.4          4         140.0        92.0         -1.284014
# 383          15.3          4         105.0        74.0          0.903093
# 384          18.2          4          91.0        68.0          1.085352
# 385          17.6          4          91.0        68.0         -0.008202
# 386          14.7          4         105.0        63.0          1.267611
# 387          17.3          4          98.0        70.0          0.903093
# 388          14.5          4         120.0        88.0          0.903093
# 389          14.5          4         107.0        75.0          0.903093
# 390          16.9          4         108.0        70.0          0.538575
# 391          15.0          4          91.0        67.0          1.267611
# 392          15.7          4          91.0        67.0          0.174057
# 393          16.2          4          91.0        67.0          1.267611
# 394          16.4          6         181.0       110.0         -1.101755
# 395          17.0          6         262.0        85.0          1.267611
# 396          14.5          4         156.0        92.0         -0.919496
# 397          14.7          6         232.0       112.0         -1.648532
# 398          13.9          4         144.0        96.0          0.174057
# 399          13.0          4         135.0        84.0          0.903093
# 400          17.3          4         151.0        90.0         -0.737237
# 401          15.6          4         140.0        86.0         -0.737237
# 402          24.6          4          97.0        52.0          2.361164
# 403          11.6          4         135.0        84.0          0.174057
# 404          18.6          4         120.0        79.0         -0.554978
# 405          19.4          4         119.0        82.0         -0.008202
#
#                                   Name  Origin  Weight_in_lbs        Year
# 0            chevrolet chevelle malibu     USA           3504  1970-01-01
# 1                    buick skylark 320     USA           3693  1970-01-01
# 2                   plymouth satellite     USA           3436  1970-01-01
# 3                        amc rebel sst     USA           3433  1970-01-01
# 4                          ford torino     USA           3449  1970-01-01
# 5                     ford galaxie 500     USA           4341  1970-01-01
# 6                     chevrolet impala     USA           4354  1970-01-01
# 7                    plymouth fury iii     USA           4312  1970-01-01
# 8                     pontiac catalina     USA           4425  1970-01-01
# 9                   amc ambassador dpl     USA           3850  1970-01-01
# 15                 dodge challenger se     USA           3563  1970-01-01
# 16                  plymouth 'cuda 340     USA           3609  1970-01-01
# 18               chevrolet monte carlo     USA           3761  1970-01-01
# 19             buick estate wagon (sw)     USA           3086  1970-01-01
# 20               toyota corona mark ii   Japan           2372  1970-01-01
# 21                     plymouth duster     USA           2833  1970-01-01
# 22                          amc hornet     USA           2774  1970-01-01
# 23                       ford maverick     USA           2587  1970-01-01
# 24                        datsun pl510   Japan           2130  1970-01-01
# 25        volkswagen 1131 deluxe sedan  Europe           1835  1970-01-01
# 26                         peugeot 504  Europe           2672  1970-01-01
# 27                         audi 100 ls  Europe           2430  1970-01-01
# 28                            saab 99e  Europe           2375  1970-01-01
# 29                            bmw 2002  Europe           2234  1970-01-01
# 30                         amc gremlin     USA           2648  1970-01-01
# 31                           ford f250     USA           4615  1970-01-01
# 32                           chevy c20     USA           4376  1970-01-01
# 33                          dodge d200     USA           4382  1970-01-01
# 34                            hi 1200d     USA           4732  1970-01-01
# 35                        datsun pl510   Japan           2130  1971-01-01
# ..                                 ...     ...            ...         ...
# 375                 chevrolet cavalier     USA           2605  1982-01-01
# 376           chevrolet cavalier wagon     USA           2640  1982-01-01
# 377          chevrolet cavalier 2-door     USA           2395  1982-01-01
# 378         pontiac j2000 se hatchback     USA           2575  1982-01-01
# 379                     dodge aries se     USA           2525  1982-01-01
# 380                    pontiac phoenix     USA           2735  1982-01-01
# 381               ford fairmont futura     USA           2865  1982-01-01
# 383                volkswagen rabbit l  Europe           1980  1982-01-01
# 384                 mazda glc custom l   Japan           2025  1982-01-01
# 385                   mazda glc custom   Japan           1970  1982-01-01
# 386             plymouth horizon miser     USA           2125  1982-01-01
# 387                     mercury lynx l     USA           2125  1982-01-01
# 388                   nissan stanza xe   Japan           2160  1982-01-01
# 389              honda Accelerationord   Japan           2205  1982-01-01
# 390                     toyota corolla   Japan           2245  1982-01-01
# 391                        honda civic   Japan           1965  1982-01-01
# 392                 honda civic (auto)   Japan           1965  1982-01-01
# 393                      datsun 310 gx   Japan           1995  1982-01-01
# 394              buick century limited     USA           2945  1982-01-01
# 395  oldsmobile cutlass ciera (diesel)     USA           3015  1982-01-01
# 396         chrysler lebaron medallion     USA           2585  1982-01-01
# 397                     ford granada l     USA           2835  1982-01-01
# 398                   toyota celica gt   Japan           2665  1982-01-01
# 399                  dodge charger 2.2     USA           2370  1982-01-01
# 400                   chevrolet camaro     USA           2950  1982-01-01
# 401                    ford mustang gl     USA           2790  1982-01-01
# 402                          vw pickup  Europe           2130  1982-01-01
# 403                      dodge rampage     USA           2295  1982-01-01
# 404                        ford ranger     USA           2625  1982-01-01
# 405                         chevy s-10     USA           2720  1982-01-01
#
# [392 rows x 9 columns]

# %% [markdown]
# Show that the average z-scores for `Miles_per_Gallon` grouped by year are all zero:

# %%
# YOUR CODE HERE
d7.groupby(['Year']).mean()
# Out:
#             Acceleration  Cylinders  Displacement  Horsepower  \
# Year
# 1970-01-01     12.948276   6.758621    281.413793  147.827586
# 1971-01-01     15.000000   5.629630    213.888889  107.037037
# 1972-01-01     15.125000   5.821429    218.375000  120.178571
# 1973-01-01     14.312500   6.375000    256.875000  130.475000
# 1974-01-01     16.173077   5.230769    170.653846   94.230769
# 1975-01-01     16.050000   5.600000    205.533333  101.066667
# 1976-01-01     15.941176   5.647059    197.794118  101.117647
# 1977-01-01     15.435714   5.464286    191.392857  105.071429
# 1978-01-01     15.805556   5.361111    177.805556   99.694444
# 1979-01-01     15.813793   5.827586    206.689655  101.206897
# 1980-01-01     17.018519   4.148148    116.074074   77.481481
# 1982-01-01     16.420690   4.413793    132.206897   81.258621
#
#             Miles_per_Gallon  Weight_in_lbs
# Year
# 1970-01-01     -7.656711e-17    3372.793103
# 1971-01-01     -2.106949e-02    3030.592593
# 1972-01-01     -2.299748e-16    3237.714286
# 1973-01-01     -3.053113e-16    3419.025000
# 1974-01-01      1.020669e-02    2878.038462
# 1975-01-01      2.960595e-16    3176.800000
# 1976-01-01     -5.224579e-17    3078.735294
# 1977-01-01      1.189525e-17    2997.357143
# 1978-01-01     -3.484867e-16    2861.805556
# 1979-01-01      1.761043e-15    3055.344828
# 1980-01-01      1.522481e-02    2441.592593
# 1982-01-01      1.442359e-02    2480.517241

# %% [markdown]
# Show that the standard deviation of the z-scores for `Miles_per_Gallon` grouped by year are all 1.0:

# %%
# YOUR CODE HERE
d7.groupby(['Year']).std()
# Out:
#             Acceleration  Cylinders  Displacement  Horsepower  \
# Year
# 1970-01-01      3.330982   1.724926    124.421380   53.734844
# 1971-01-01      2.605468   1.667521    115.152185   38.566109
# 1972-01-01      2.850032   2.073708    123.781964   41.121368
# 1973-01-01      2.754222   1.807215    121.722085   46.412304
# 1974-01-01      1.714306   1.607674     94.259193   29.686775
# 1975-01-01      2.471737   1.522249     87.669730   26.577062
# 1976-01-01      2.801419   1.667558     94.422256   32.430592
# 1977-01-01      2.273391   1.815206    107.813742   36.095479
# 1978-01-01      2.129915   1.495761     76.012713   28.436214
# 1979-01-01      2.952931   1.774199     96.307581   28.455955
# 1980-01-01      2.885379   0.601518     34.164676   18.173037
# 1982-01-01      2.311888   0.899015     49.762157   15.661508
#
#             Miles_per_Gallon  Weight_in_lbs
# Year
# 1970-01-01          1.000000     852.868663
# 1971-01-01          1.012696    1065.314842
# 1972-01-01          1.000000     974.520960
# 1973-01-01          1.000000     974.809133
# 1974-01-01          1.018369     968.108402
# 1975-01-01          1.000000     765.179781
# 1976-01-01          1.000000     821.371481
# 1977-01-01          1.000000     912.825902
# 1978-01-01          1.000000     626.023907
# 1979-01-01          1.000000     747.881497
# 1980-01-01          0.978385     422.864614
# 1982-01-01          0.995088     448.766037

# %% [markdown]
# ## Grouped missing value replacement

# %% [markdown]
# ## Introduce missing values

# %% [markdown]
# Let's introduce some missing values into the `Cylinders` column:

# %%
cars['Cylinders'] = np.where(np.random.rand(len(cars)) > 0.8, np.nan, cars['Cylinders'])
cars.Cylinders
# Out:
# 0      NaN
# 1      NaN
# 2      8.0
# 3      8.0
# 4      8.0
# 5      NaN
# 6      8.0
# 7      8.0
# 8      8.0
# 9      NaN
# 10     4.0
# 11     8.0
# 12     8.0
# 13     8.0
# 14     8.0
# 15     8.0
# 16     NaN
# 17     8.0
# 18     NaN
# 19     NaN
# 20     4.0
# 21     NaN
# 22     6.0
# 23     6.0
# 24     4.0
# 25     4.0
# 26     4.0
# 27     NaN
# 28     4.0
# 29     4.0
#       ...
# 376    4.0
# 377    4.0
# 378    4.0
# 379    4.0
# 380    4.0
# 381    4.0
# 382    4.0
# 383    4.0
# 384    4.0
# 385    4.0
# 386    4.0
# 387    4.0
# 388    4.0
# 389    4.0
# 390    4.0
# 391    4.0
# 392    4.0
# 393    NaN
# 394    6.0
# 395    6.0
# 396    4.0
# 397    NaN
# 398    4.0
# 399    NaN
# 400    4.0
# 401    4.0
# 402    NaN
# 403    4.0
# 404    4.0
# 405    4.0
# Name: Cylinders, dtype: float64

# %%
cars.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0        NaN         307.0       130.0              18.0
# 1          11.5        NaN         350.0       165.0              15.0
# 2          11.0        8.0         318.0       150.0              18.0
# 3          12.0        8.0         304.0       150.0              16.0
# 4          10.5        8.0         302.0       140.0              17.0
#
#                         Name Origin  Weight_in_lbs        Year
# 0  chevrolet chevelle malibu    USA           3504  1970-01-01
# 1          buick skylark 320    USA           3693  1970-01-01
# 2         plymouth satellite    USA           3436  1970-01-01
# 3              amc rebel sst    USA           3433  1970-01-01
# 4                ford torino    USA           3449  1970-01-01

# %% [markdown]
# Here are the average number of Cylinders, grouped by `Year`:

# %%
cars.groupby(['Year'])['Cylinders'].mean()
# Out:
# Year
# 1970-01-01    6.640000
# 1971-01-01    5.391304
# 1972-01-01    5.352941
# 1973-01-01    6.346154
# 1974-01-01    5.333333
# 1975-01-01    5.750000
# 1976-01-01    5.733333
# 1977-01-01    5.285714
# 1978-01-01    5.137931
# 1979-01-01    5.730769
# 1980-01-01    4.181818
# 1982-01-01    4.307692
# Name: Cylinders, dtype: float64

# %% [markdown]
# Replace the missing values in `Cylinders` by the group average (grouped by `Year`):

# %%
# YOUR CODE HERE
cars['Cylinders'] = cars.groupby(['Year'])['Cylinders'].transform(lambda x: x.fillna(x.mean()))

#df.groupby("name").transform(lambda x: x.fillna(x.mean()))

# %% [markdown]
# By replacing missing values with group averages, the grouped averages remain unchanged:

# %%
# YOUR CODE HERE
cars.groupby(['Year'])['Cylinders'].mean()
# Out:
# Year
# 1970-01-01    6.640000
# 1971-01-01    5.391304
# 1972-01-01    5.352941
# 1973-01-01    6.346154
# 1974-01-01    5.333333
# 1975-01-01    5.750000
# 1976-01-01    5.733333
# 1977-01-01    5.285714
# 1978-01-01    5.137931
# 1979-01-01    5.730769
# 1980-01-01    4.181818
# 1982-01-01    4.307692
# Name: Cylinders, dtype: float64
